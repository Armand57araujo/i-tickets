# %%
! pip install kagglehub
import requests
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from prophet import Prophet
import datetime as dt
import kagglehub as k
import json

# Download latest version
path = kagglehub.dataset_download("rajugc/imdb-movies-dataset-based-on-genre")

# List files in the downloaded directory
files_1 = os.listdir(path)

print("Files in the directory:", files)

# Assuming the CSV file is named 'imdb_movies.csv' (replace with the actual file name)
csv_file = [file for file in files if file.endswith('.csv')][0]  # Get the first CSV file found

# Load the CSV file into a DataFrame
imdb_movies_by_genre_df = pd.read_csv(os.path.join(path, csv_file))

# Display the first few rows of the DataFrame
imdb_movies_by_genre_df

# Save the DataFrame to a CSV file
df.to_csv('imdb_movies_by_genre_dataset.csv', index = False)

print("DataFrame saved as 'imdb_movies_by_genre_dataset.csv'")

# %%
# Download latest version
path = kagglehub.dataset_download("parthdande/movies-box-office-collection-data-2000-2024")

# List files in the downloaded directory
files = os.listdir(path)

print("Files in the directory:", files)

# Assuming the CSV file is named 'imdb_movies.csv' (replace with the actual file name)
csv_file = [file for file in files if file.endswith('.csv')][0]  # Get the first CSV file found

# Load the CSV file into a DataFrame
movies_box_office_2000_to_2024_df = pd.read_csv(os.path.join(path, csv_file))

# Display the first few rows of the DataFrame
movies_box_office_2000_to_2024_df

# Save the DataFrame to a CSV file
df.to_csv('movies_box_office_2000_to_2024.csv', index = False)

print("DataFrame saved as 'movies_box_office_2000_to_2024.csv'")

# %%
# Download latest version
path = kagglehub.dataset_download("delfinaoliva/movies")

# List files in the downloaded directory
files = os.listdir(path)

print("Files in the directory:", files)

# Assuming the CSV file is named 'imdb_movies.csv' (replace with the actual file name)
csv_file = [file for file in files if file.endswith('.csv')][0]  # Get the first CSV file found

# Load the CSV file into a DataFrame
imdb_movies_1930_to_2016_df = pd.read_csv(os.path.join(path, csv_file))

# Display the first few rows of the DataFrame
imdb_movies_1930_to_2016_df

# Save the DataFrame to a CSV file
df.to_csv('imdb_movies_1930_to_2016.csv', index = False)

print("DataFrame saved as 'box_office_mojo_dataset_1990_to_April_2020.csv'")

# %%
# Download latest version
path = kagglehub.dataset_download("igorkirko/wwwboxofficemojocom-movies-with-budget-listed")

# List files in the downloaded directory
files = os.listdir(path)

print("Files in the directory:", files)

# Assuming the CSV file is named 'imdb_movies.csv' (replace with the actual file name)
csv_file = [file for file in files if file.endswith('.csv')][0]  # Get the first CSV file found

# Load the CSV file into a DataFrame
mojo_dataset_1990_April_2020_df = pd.read_csv(os.path.join(path, csv_file))

# Display the first few rows of the DataFrame
mojo_dataset_1990_April_2020_df

# Save the DataFrame to a CSV file
df.to_csv('mojo_dataset_1990_April_2020.csv', index = False)

print("DataFrame saved as 'mojo_dataset_1990_April_2020.csv'")
